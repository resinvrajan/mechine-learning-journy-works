# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\RABIN RESIN\\Desktop\\luminar\\development-journey\\mechine learning journey\\feature engineering\\tasks\\Task 16  Mobile battery 05-02-2026\\mobile battery with time.csv")
df.shape
# Out:
# (385429, 18)

# %%
df.columns
# Out:
# Index(['352944080639365', 'samsung SM-A910F', '8.0.0', 'Li-ion', '5000.0',
#        '1570599938843', 'false', '37', 'com.zopper.batteryage', '0', '24.7',
#        '3741', '130', 'none', 'false.1', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17'],
#       dtype='object')

# %%
df.head()
# Out:
#    352944080639365  samsung SM-A910F  8.0.0  Li-ion  5000.0  1570599938843  \
# 0  352944080639365  samsung SM-A910F  8.0.0  Li-ion  5000.0  1570599942514
# 1  352944080639365  samsung SM-A910F  8.0.0  Li-ion  5000.0  1570599942526
# 2  352944080639365  samsung SM-A910F  8.0.0  Li-ion  5000.0  1570599946877
# 3  352944080639365  samsung SM-A910F  8.0.0  Li-ion  5000.0  1570599947492
# 4  352944080639365  samsung SM-A910F  8.0.0  Li-ion  5000.0  1570599953460
#
#    false  37  com.zopper.batteryage  0  24.7  3741  130  none  false.1  \
# 0  False  37  com.zopper.batteryage  0  24.7  3763  130  none    False
# 1  False  37  com.zopper.batteryage  0  24.7  3763  130  none    False
# 2  False  37  com.zopper.batteryage  0  24.7  3763  130  none    False
# 3  False  37  com.zopper.batteryage  0  24.7  3763  130  none    False
# 4  False  37  com.zopper.batteryage  0  24.7  3763  130  none    False
#
#    Unnamed: 15  Unnamed: 16  Unnamed: 17
# 0          NaN          NaN          NaN
# ...

# %%
df.isnull().sum()
# Out:
# 352944080639365               0
# samsung SM-A910F              0
# 8.0.0                         0
# Li-ion                        0
# 5000.0                        0
# 1570599938843                 0
# false                         0
# 37                            0
# com.zopper.batteryage         0
# 0                             0
# 24.7                          0
# 3741                          0
# 130                           0
# none                          0
# false.1                       0
# Unnamed: 15              385429
# Unnamed: 16              385429
# Unnamed: 17              385429
# dtype: int64

# %%
df.drop(columns=["Unnamed: 15","Unnamed: 16","Unnamed: 17","none"])
# Out:
#         352944080639365  samsung SM-A910F  8.0.0  Li-ion  5000.0  \
# 0       352944080639365  samsung SM-A910F  8.0.0  Li-ion  5000.0
# 1       352944080639365  samsung SM-A910F  8.0.0  Li-ion  5000.0
# 2       352944080639365  samsung SM-A910F  8.0.0  Li-ion  5000.0
# 3       352944080639365  samsung SM-A910F  8.0.0  Li-ion  5000.0
# 4       352944080639365  samsung SM-A910F  8.0.0  Li-ion  5000.0
# ...                 ...               ...    ...     ...     ...
# 385424  352944080639365  samsung SM-A910F  8.0.0  Li-ion  5000.0
# 385425  352944080639365  samsung SM-A910F  8.0.0  Li-ion  5000.0
# 385426  352944080639365  samsung SM-A910F  8.0.0  Li-ion  5000.0
# 385427  352944080639365  samsung SM-A910F  8.0.0  Li-ion  5000.0
# 385428  352944080639365  samsung SM-A910F  8.0.0  Li-ion  5000.0
#
#         1570599938843  false  37  com.zopper.batteryage  0  24.7  3741   130  \
# 0       1570599942514  False  37  com.zopper.batteryage  0  24.7  3763   130
# ...
